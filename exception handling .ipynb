# %% [markdown]
# # Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")     
from selenium.webdriver.common.by import By 
import time

# %%
from selenium.common.exceptions import  StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome(r'chromedriver')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="780013946fc9d2e95902dc4e4abc44ad")>

# %%
driver.get('https://www.amazon.in/')

# %%
product=(input('please enter product details ')+'s')
# Out:
# please enter product details guitar

# %%
product_search=driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
product_search.send_keys(product)

# %%
driver.close()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results thenscrape all the products available under that product name.
# Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://www.amazon.in/')

# %%
product=(input('please enter product details ')+'s')
# Out:
# please enter product details guitar

# %%
product_search=driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
product_search.send_keys(product)

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
url=[]

# %%
for page in range (1,3):
    try:
       
        url_tags=driver.find_elements(By.XPATH, '//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]' )
        for i in url_tags:
            url.append(i.get_attribute('href'))
    except NoSuchElementException:
          url.append('-')
        
        
    next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(5)

# %%
print(len(url))
# Out:
# 120

# %%
brand_name=[]
product_name=[]
price=[]
return_exchange=[]
expected_delivery=[]
availability=[]

# %%
driver=webdriver.Chrome(r'chromedriver')
for details in url:
    driver.get(details)
    time.sleep(5)
    
    try:
        brand_tags= driver.find_elements(By.XPATH,'//tr[@class="a-spacing-small po-brand"]/td[2]')
        for i in brand_tags:
            brand_name.append(i.text)
            
            
    except NoSuchElementException:
        brand_name.append('No details')
        
        
    try:
        product_tags=driver.find_elements(By.XPATH,'//h1[@class="a-size-large a-spacing-none"]')
        for i in product_tags:
            product_name.append(i.text)
        
    except NoSuchElementException:
        brand_name.append('No details')
        
    try:
        price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price aok-align-center"]')
        for i in price_tags:
            price.append(i.text)
            
        
    except NoSuchElementException:
        brand_name.append('No details')
        
        
    try:
        exchange_tags= driver.find_elements(By.XPATH,'//span[@class="a-declarative"]/div/a')
        for i in exchange_tags:
            return_exchange.append(i.text)
            
    except NoSuchElementException:
        return_exchange.append('No details')
        
        
    try:
        delivery_tags= driver.find_elements(By.XPATH,'//div[@class="a-spacing-base"]/span/span[1]')
        for i in delivery_tags:
                expected_delivery.append(i.text)
                
    except NoSuchElementException:
        expected_delivery.append('No details')
        
        
    try:
        availability_tags = driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-micro }"]')
        for i in availability_tags:
            availability.append(i.text)
            
            
    except NoSuchElementException:
        availability.append('No details')

# %%
print(len(brand_name),len(product_name),len(price),len(exchange),len(delivery),len(availability))
# Out:
# 104 104 104 104 104 104

# %%
amont=[]

for i in price:
    amont.append(i.split('\n')[0])

# %%
df=pd.DataFrame({'PRODUCT_NAME': product_name,'BRAND':brand_name,'price':amont,'Return_Exchange':exchange,'Delivery':delivery,'Availability':availability})
df
# Out:
#                                           PRODUCT_NAME      BRAND    price  \
# 0    Kadence Frontier Jumbo Semi Acoustic Guitar Wi...    Kadence   ₹6,899
# 1    Kadence Frontier guitar with Online Guitar lea...    Kadence   ₹4,444
# 2    INTERN 40 inches Acoustic Guitar with Pick-up ...     Intern   ₹4,581
# 3    Vault DA40 41 Inch Premium Solid Spruce-Top Dr...      VAULT   ₹6,925
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...     JUAREZ   ₹1,999
# ..                                                 ...        ...      ...
# 99         YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR  blueberry   ₹7,727
# 100  Vault Traveller 34 Inch Acoustic Guitar With T...  blueberry   ₹4,084
# 101  Epiphone Les Paul Muse Electric Guitar - Wande...    Kadence  ₹53,948
# 102  Blueberry B40L, 40" Acoustic Guitar Kit Inbuil...     Fender   ₹4,270
# 103  Blueberry VIP 405, 40 Inch Cutaway Acoustic Gu...     Fender   ₹4,360
#
#         Return_Exchange             Delivery Availability
# 0    7 days Replacement   Thursday, 20 April     In stock
# 1    7 days Replacement  Wednesday, 19 April     In stock
# 2    7 days Replacement  Wednesday, 19 April     In stock
# 3    7 days Replacement    Tuesday, 18 April     In stock
# 4    7 days Replacement    Tuesday, 18 April     In stock
# ..                  ...                  ...          ...
# 99   7 days Replacement  Wednesday, 19 April     In stock
# 100  7 days Replacement    Tuesday, 18 April     In stock
# 101  7 days Replacement   Thursday, 20 April     In stock
# 102  7 days Replacement    Tuesday, 18 April     In stock
# 103  7 days Replacement   Thursday, 20 April     In stock
#
# [104 rows x 6 columns]

# %% [markdown]
# #  3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://images.google.com/')

# %%
search=driver.find_element(By.CLASS_NAME,'gLFyf')
search.send_keys('fruits')

# %%
find=driver.find_element(By.CLASS_NAME,'zgAlFc')
find.click()

# %%
fruit_tags=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in fruit_tags[0:10]:
    fruit.append(i.get_attribute('src'))

# %%
cr=driver.find_element(By.CLASS_NAME,'og3lId')
cr.clear()

# %%
cr.send_keys('car')

# %%
clk=driver.find_element(By.CLASS_NAME,'rCGXm')
clk.click()

# %%
fruit=[]
car=[]
Machine_Learning=[]
Guitar=[]
Cakes=[]

# %%
car_tags= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in car_tags[0:10]:
    car.append(i.get_attribute('src'))
    
cr=driver.find_element(By.CLASS_NAME,'og3lId')
cr.clear()

cr.send_keys('Machine Learning')

clk=driver.find_element(By.CLASS_NAME,'rCGXm')
clk.click()


Machine_Learning_tags= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in Machine_Learning_tags[0:10]:
    Machine_Learning.append(i.get_attribute('src'))

cr=driver.find_element(By.CLASS_NAME,'og3lId')
cr.clear()

cr.send_keys('Guitar')

Guitar=[]
Guitar_tags= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for i in Guitar_tags[0:10]:
    Guitar.append(i.get_attribute('src'))

cr=driver.find_element(By.CLASS_NAME,'og3lId')
cr.clear()

cr.send_keys('Cakes')

Cakes=[]
Cakes_tags= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]
marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGMWBYUWY2EMNU.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/realme-c33-2023-sandy-gold-64-gb/p/itmdfad610ca6eff?pid=MOBGMWBYFKUYZFZA&lid=LSTMOBGMWBYFKUYZFZAG8DUMK&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGMWBYFKUYZFZA.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&lid=LSTMOBGENJWBPFYJSFTP8FGOC&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGENJWBPFYJSFT.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/samsung-galaxy-f13-nightsky-green-64-gb/p/itmeadfda1bd23fa?pid=MOBGENJWF4KJTPEN&lid=LSTMOBGENJWF4KJTPENS2XJXA&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGENJWF4KJTPEN.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/infinix-hot-30i-glacier-blue-128-gb/p/itm8b42a43b35895?pid=MOBGNPK2ZTGZBRXE&lid=LSTMOBGNPK2ZTGZBRXEAFQ5YT&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGNPK2ZTGZBRXE.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/poco-m4-pro-yellow-128-gb/p/itm675edffaf085d?pid=MOBGBTHFCY9DADTY&lid=LSTMOBGBTHFCY9DADTYZTJMWM&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGBTHFCY9DADTY.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/infinix-hot-30i-mirror-black-64-gb/p/itm8b42a43b35895?pid=MOBGNPK2QRUEBEHG&lid=LSTMOBGNPK2QRUEBEHGKBH4RF&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGNPK2QRUEBEHG.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/motorola-e13-aurora-green-64-gb/p/itm3042ad3770a18?pid=MOBGKHNBA55HDSZR&lid=LSTMOBGKHNBA55HDSZRHOAFME&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGKHNBA55HDSZR.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/poco-c50-country-green-32-gb/p/itmceaa9370920fd?pid=MOBGK8WZYEJ3G5AA&lid=LSTMOBGK8WZYEJ3G5AAMF47BF&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGK8WZYEJ3G5AA.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/motorola-g52-metallic-white-128-gb/p/itm469efad765b98?pid=MOBGAKFYDDSNZGR8&lid=LSTMOBGAKFYDDSNZGR8W6QBUV&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGAKFYDDSNZGR8.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/infinix-hot-30i-glacier-blue-64-gb/p/itm8b42a43b35895?pid=MOBGNPK2BBNPWJYR&lid=LSTMOBGNPK2BBNPWJYRIQDVWM&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGNPK2BBNPWJYR.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/motorola-g32-mineral-gray-128-gb/p/itm6061450cb40ac?pid=MOBGM2EHJUTMXMFV&lid=LSTMOBGM2EHJUTMXMFVL5MPKC&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=38a85a2f-d2c4-4712-b0a0-6e2db2590339.MOBGM2EHJUTMXMFV.SEARCH&ppt=hp&ppn=homepage&ssid=vrlxv6mf000000001682001509289&qH=1036ba3c4ed2c021']

# %%
print(len(url))
# Out:
# 24

# %%
brand=[]
name=[]
colour=[]
ram=[]
storage=[]
camera=[]
secondary_camera=[]
display=[]
battery=[]
price=[]

# %%
driver=webdriver.Chrome(r'chromedriver')
for details in url:
    driver.get(details)
    time.sleep(5)
    
    try:
        name_tags=driver.find_elements(By.XPATH,'//span[@class="B_NuCI"]')
        for i in name_tags:
            name.append(i.text)
            
    except NoSuchElementException:
        name.append('No details')

    
    try:
        
        brand_tags=driver.find_elements(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]')
        for i in brand_tags:
            brand.append(i.text)
            
    except NoSuchElementException:
        brand.append('No details')
        
       
        
    try:
        colour_tags=driver.find_elements(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        for i in colour_tags:
            colour.append (i.text)
            
            
    except NoSuchElementException:
        colour.append('No details')  
        
 #Ram       
    try:
        storage_tags=driver.find_elements(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        for i in storage_tags:
            storage.append(i.text)
            
    except NoSuchElementException:
        storage.append('No details')  
        
        
#rom  
    try:
        ram_tags=driver.find_elements(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        for i in ram_tags:
            ram.append(i.text)
            
    except NoSuchElementException:
        ram.append('No details')
 
        
#display
    
    try:
        display_tags=driver.find_elements(By.XPATH,'//div[@class="_2418kt"]/ul/li[2]')
        for i in display_tags:
            display.append(i.text)

            
    except NoSuchElementException:
        display.append('No details')  
        

         
#camera  
    try:
        camera_tags=driver.find_elements(By.XPATH,'//div[@class="_2418kt"]/ul/li[3]')
        for i in camera_tags:
            camera.append(i.text.split('|')[0])
            
    except NoSuchElementException:
        camera.append('No details') 
        
        
    try:
        secondary_camera_tags=driver.find_elements(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[6]/td[2]/ul/li')
        for i in secondary_camera_tags:
            secondary_camera.append(i.text)
            
    except NoSuchElementException:
        secondary_camera.append('No details') 
        
#battery  
      
        
    try:
        battery_tags=driver.find_elements(By.XPATH,'//div[@class="_2418kt"]/ul/li[4]')
        for i in battery_tags:
            battery.append(i.text)
            
    except NoSuchElementException:
        battery.append('No details')  
    
# price
    try:
        price_tags= driver.find_elements(By.XPATH,'//div[@class="dyC4hf"]/div/div/div[1]')
        for i in price_tags:
            price.append(i.text)
            
    except NoSuchElementException:
        price.append('No details')

# %%
print(len(name),len(brand),len(colour),len(ram),len(storage),len(camera),len(display),len(battery),len(price),len(secondary_camera))
# Out:
# 23 23 23 23 23 23 23 23 23 23

# %%
df=pd.DataFrame({'name':name,'Brand':brand,'colour':colour,'ram':ram,'camera':camera,'display':display,'storage':storage,'secondary_camera':secondary_camera,'battery':battery,'price':price})
df
# Out:
#                                                  name       Brand  \
# 0          REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)          10
# 1           POCO M4 5G (Cool Blue, 64 GB)  (4 GB RAM)       M4 5G
# 2        REDMI 10 (Midnight Black, 64 GB)  (4 GB RAM)          10
# 3        POCO M4 5G (Power Black, 128 GB)  (6 GB RAM)       M4 5G
# 4             POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)         C55
# 5            POCO C50 (Royal Blue, 32 GB)  (2 GB RAM)         C50
# 6         POCO M4 5G (Power Black, 64 GB)  (4 GB RAM)       M4 5G
# 7            POCO C50 (Royal Blue, 32 GB)  (3 GB RAM)         C50
# 8   SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...  Galaxy F04
# 9                  APPLE iPhone 13 (Midnight, 128 GB)   iPhone 13
# 10  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB
# 16               16.76 cm (6.6 inch) HD+ Display
# 17  16.33 cm (6.43 inch) Full HD+ AMOLED Display
# 18               16.76 cm (6.6 inch) HD+ Display
# 19               16.51 cm (6.5 inch) HD+ Display
# 20              16.56 cm (6.52 inch) HD+ Display
# 21          16.76 cm (6.6 inch) Full HD+ Display
# 22               16.76 cm (6.6 inch) HD+ Display
#
#                                  battery    price
# 0       6000 mAh Lithium Polymer Battery   ₹9,999
# 1   5000 mAh Lithium Ion Polymer Battery  ₹10,999
# 2       6000 mAh Lithium Polymer Battery   ₹9,999
# 3   5000 mAh Lithium Ion Polymer Battery  ₹12,999
# 4                       5000 mAh Battery   ₹8,499
# 5       5000 mAh Lithium Polymer Battery   ₹6,499
# 6   5000 mAh Lithium Ion Polymer Battery  ₹10,999
# 7       5000 mAh Lithium Polymer Battery   ₹7,299
# 8           5000 mAh Lithium-Ion Battery   ₹7,499
# 9              A15 Bionic Chip Processor  ₹61,999
# 10          6000 mAh Lithium Ion Battery  ₹11,999
# 11          5000 mAh Lithium Ion Battery   ₹9,999
# 12          5000 mAh Lithium Ion Battery   ₹9,999
# 13          5000 mAh Lithium Ion Battery   ₹9,999
# 14          6000 mAh Lithium Ion Battery  ₹10,999
# 15          6000 mAh Lithium Ion Battery  ₹10,999
# 16                      5000 mAh Battery   ₹9,499
# 17  5000 mAh Lithium-ion Polymer Battery  ₹12,999
# 18                      5000 mAh Battery   ₹8,399
# 19                      5000 mAh Battery   ₹7,999
# 20      5000 mAh Lithium Polymer Battery   ₹6,499
# 21              5000 mAh Lithium Battery  ₹12,999
# 22                      5000 mAh Battery   ₹8,399

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://www.google.com/maps/@19.1540122,73.0270505,11.25z')

# %%
try:
    url_string=driver.current_url
    print('url extracted: ',url_string)
    
    lat_lng= re.findall(r'@(.*)data',url_string)
    
except NoSuchElementException:
    availability.append('No details')
# Out:
# url extracted:  https://www.google.com/maps/@19.1540122,73.0270505,11.25z

# %% [markdown]
# # 6. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://www.digit.in/')

# %%
laptop=driver.find_element(By.XPATH,'/html/body/div[7]/div/div[2]/div[2]/div[3]/ul/li[9]/a')
laptop.click()

# %%
gamming_laptop=[]
processor=[]
display=[]
os=[]
memory=[]
graphic=[]
body=[]
price=[]

# %%
try:
    laptop_tags=driver.find_elements(By.XPATH,'//div[@class="left_side"]')
    for i in laptop_tags[0:10]:
         gamming_laptop.append(i.text.split('\n')[1])
except NoSuchElementException:
         laptop.append('No details')


try:
    processor_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[2]/td[3]')
    for i in processor_tags:
        processor.append(i.text)
except NoSuchElementException:
         processor.append('No details')
            
try:
    display_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
    for i in display_tags:
        display.append(i.text)
except NoSuchElementException:
         display.append('No details')
            
            
try:
    os_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
    for i in os_tags:
        os.append(i.text)
except NoSuchElementException:
         os.append('No details')
            
try:
    memory_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
    for i in memory_tags:
        memory.append(i.text)
except NoSuchElementException:
         memory.append('No details')

try:
    graphic_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
    for i in graphic_tags:
        graphic.append(i.text)
except NoSuchElementException:
         graphic.append('No details')
            
try:
    body_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
    for i in body_tags:
        body.append(i.text)
except NoSuchElementException:
         body.append('No details')
            
try:
    price_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
    for i in price_tags:
        price.append(i.text)
except NoSuchElementException:
         price.append('No details')

# %%
df=pd.DataFrame({'gamming laptop':gamming_laptop,'Processor':processor,'display':display,'Operatin System':'os','memory':memory,
                'graphic':graphic,'body':body})

df
# Out:
#                                   gamming laptop  \
# 0                           MSI Titan GT77-12UHS
# 1                                Lenovo Legion 7
# 2                               Alienware X17 R2
# 3          Acer Predator Triton 500 SE PT516-52s
# 4                        Omen By HP (16-B1371TX)
# 5              Acer Predator Helios 300 AN515-45
# 6                     MSI Delta 15 (A5EFK-083IN)
# 7                        Omen By HP (16-C0141AX)
# 8              Lenovo Legion 5i Pro (82RF00MGIN)
# 9  Alienware M15 R5 Ryzen Edition Icc-C780001win
#
#                                            Processor  \
# 0   12th Gen Intel Core i9-12900HX 16 core processor
# 1  12th Gen Intel Core i9-12900HX 16 core process...
# 2  12th Gen Intel Core i9-12900H 14 core processo...
# 3  12th Gen Intel Core i7-12700H 14 core processo...
# 4  12th Gen Intel Core i7-12700H 14 core processo...
# 5                AMD Ryzen 9-5900HX 8 core processor
# 6  AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 7  AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 8  12th Gen Intel Core i7-12700H 14 core processo...
# 9  AMD Ryzen R7-5800H 8 core processor with 4.40 ...
#
#                                            display Operatin System  \
# 0  17.3″ (3840 x 2160) screen, 120 Hz refresh rate              os
# 1    16″ (2560 x 1600) screen, 165 Hz refresh rate              os
# 2  17.3″ (1920 x 1080) screen, 360 Hz refresh rate              os
# 3                         16″ (2560 x 1600) screen              os
# 4                       16.1″ (2560 x 1440) screen              os
# 5  15.6″ (2560 x 1440) screen, 165 Hz refresh rate              os
# 6   15.6″ (1920 x 1080) screen, 240Hz refresh rate              os
# 7                       16.1″ (2560 x 1440) screen              os
# 8    16″ (2560 x 1600) screen, 165 Hz refresh rate              os
# 9   15.6″ (1920 x 1080) screen, 165Hz refresh rate              os
#
#                           memory  \
# 0    64 GB DDR5GB RAM & 2 TB SSD
# 1    32 GB DDR4GB RAM & 1 TB SSD
# 2    32 GB DDR5GB RAM & 1 TB SSD
# 3    32 GB DDR5GB RAM & 2 TB SSD
# 4     8 GB DDR5GB RAM & 1 TB SSD
# 5  16 GB DDR4GB RAM & 512 GB SSD
# 6    16 GB DDR4GB RAM & 1 TB SSD
# 7   16 GB DDR4GB RAM & 1 TB NVMe
# 8    16 GB DDR5GB RAM & 1 TB SSD
# 9  16 GB DDR4GB RAM & 512 GB SSD
#
#                                              graphic  \
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 1  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 2  16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...
# 3  8 GB DDR6 NVIDIA GeForce RTX 3070 Ti Graphics ...
# 4   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 6       10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 7      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
#
#                                                 body price
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight  None
# 1       358 x 264 x 19 mm dimension & 2.53 kg weight  None
# 2       299 x 359 x 21 mm dimension & 2.96 kg weight  None
# 3        262 x 359 x 20 mm dimension & 2.4 kg weight  None
# 4       369 x 248 x 23 mm dimension & 2.32 kg weight  None
# 5      363 x 255 x 23.9 mm dimension & 2.4 kg weight  None
# 6        357 x 247 x 19 mm dimension & 1.9 kg weight  None
# 7    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight  None
# 8       360 x 264 x 20 mm dimension & 2.49 kg weight  None
# 9  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...  None

# %% [markdown]
# # Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped:
# “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://www.forbes.com/?sh=4c7be0ee2254')

# %%
billionaire= driver.find_element(By.XPATH,'//a[@class="headlink"]')
billionaire.click()

# %%
rank=[]
name=[]
worth=[]
age=[]
citizenship=[]
source=[]
industry=[]

# %%
try:
    rank_tags=driver.find_elements(By.XPATH,'//div[1][@class="TableRow_cell__db-hv Table_cell__houv9"]')
    for i in rank_tags:
        rank.append(i.text)
        
except NoSuchElementException:
         rank.append('No details')
        
try:
    
    name_tags=driver.find_elements(By.XPATH,'//div[2][@class="TableRow_cell__db-hv Table_cell__houv9"]')
    for i in name_tags:
         name.append(i.text)
            
except NoSuchElementException:
    name.append('No details')
    
try:
    worth_tags=driver.find_elements(By.XPATH,'//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
    for i in worth_tags:
        worth.append(i.text)
        
except NoSuchElementException:
         worth.append('No details')
        
try:
    age_tags=driver.find_elements(By.XPATH,'//div[4][@class="TableRow_cell__db-hv Table_cell__houv9"]')
    for i in age_tags:
        age.append(i.text)
        
except NoSuchElementException:
    age.append('No details')
    

try:
    citizenship_tags=driver.find_elements(By.XPATH,'//div[5][@class="TableRow_cell__db-hv Table_cell__houv9"]')
    for i in citizenship_tags:
        citizenship.append(i.text)

except NoSuchElementException:
    citizenship.append('No details')      
    
    
try:
    source_tags=driver.find_elements(By.XPATH,'//div[6][@class="TableRow_cell__db-hv Table_cell__houv9"]/div')
    for i in citizenship_tags:
        source.append(i.text)
        
except NoSuchElementException:
    source.append(i.text)
    

try:
    industry_tags=driver.find_elements(By.XPATH,'//div[7][@class="TableRow_cell__db-hv Table_cell__houv9"]/div')
    for i in industry_tags:
        industry.append(i.text)
        
except NoSuchElementException:
    industry.append(i.text)

# %%
print(len(name),len(worth),len(age),len(citizenship),len(source),len(industry))
# Out:
# 200 200 200 200 200 200

# %%
df=pd.DataFrame({'NAME OF BILLIONER':name,'NET WORTH':worth,'AGE':age,'CITIZENSHIP':citizenship,'SOURCE':source,'INDUSTRY':industry})
df
# Out:
#             NAME OF BILLIONER NET WORTH AGE    CITIZENSHIP         SOURCE  \
# 0    Bernard Arnault & family    $211 B  74         France         France
# 1                   Elon Musk    $180 B  51  United States  United States
# 2                  Jeff Bezos    $114 B  59  United States  United States
# 3               Larry Ellison    $107 B  78  United States  United States
# 4              Warren Buffett    $106 B  92  United States  United States
# ..                        ...       ...  ..            ...            ...
# 195               Jin Baofang    $9.6 B  70          China          China
# 196        Luo Liguo & family    $9.6 B  67          China          China
# 197              Marijke Mars    $9.6 B  58  United States  United States
# 198               Pamela Mars    $9.6 B  62  United States  United States
# 199              Valerie Mars    $9.6 B  64  United States  United States
#
#     INDUSTRY
# 0
# 1
# 2
# 3
# 4
# ..       ...
# 195
# 196
# 197
# 198
# 199
#
# [200 rows x 6 columns]

# %%
driver.quit()

# %% [markdown]
# #  8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://www.youtube.com/')

# %%
search=driver.find_element(By.XPATH,'//input[@class="ytd-searchbox"]')
search.send_keys('Pushpa-2 trailor')

# %%
find=driver.find_element(By.XPATH,'//button[@class="style-scope ytd-searchbox"]')
find.click()

# %%
trailor=driver.find_element(By.XPATH,'//a[@class="yt-simple-endpoint style-scope ytd-video-renderer"]')
trailor.click()

# %%
comment=[]
vote=[]
time=[]

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
    
    comment_tags=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')
    
    try:
        comment_tags=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')
        for i in comment_tags[0:1000]:
            comment.append(i.text)
    
    except NoSuchElementException:
         comment.append('No details')
            
    try:
        vote_tags=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
        for i in vote_tags[0:1000]:
            vote.append(i.text)
            
    except NoSuchElementException:
         vote.append('No details')
            
            
    try:
        time_tags= driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
        for i in time_tags[0:1000]:
            time.append(i.text)
            
    except NoSuchElementException:
         time.append('No details')

# %%
print(len(comment),len(vote),len(time))
# Out:
# 2298 2298 2298

# %%
df=pd.DataFrame({'COMMENT':comment,'vote':vote,'time':time})
print(df.shape)
df.head(30)
# Out:
# (2298, 3)
#                                               COMMENT vote  \
# 0   I don't know it's it's original story or not, ...   56
# 1   2 min. Silence for those people who take it se...    5
# 2         when i feel really useless...\ni watch this   30
# 3   Puspa 1 mahine se gayab tha kyuki wo Rocky ko ...    3
# 4   ARE AAJ. SHAM TAK PUSHPA 2 KA OFFICIAL TEASER ...   19
# 5           Epic film in the history of Indian cinema    3
# 6                                  Interesting story     1
# 7    ….WE.   are. Waiting.  for….PUSHPA…….! USA 🇺🇸 LA    2
# 8   Bhai aaj uska teaser aaya hai usse dekho your ...   15
# 9   Achha hai, lekin sab log party karte huye mar ...   69
# 10                   Well tried to explain own story     3
# 11  after listening to your story I can say beyond...    1
# 12                               IAM EXCITED PUSHPA 2    1
# 13     BHAI    PUS᭄HPA    3      BHI     AAYEGI   KYA    5
# 14  Real story shydd kuch or hogi par tumne bhi ac...   26
# 15               Bhai real storie lag rahi hey sachme    2
# 16  Bhai ye pushpa ka background music hai.\nReal ...    5
# 17                                 I really trust him    6
# 18  Puri movie ko 10min me suna kar khatm kar diya...    5
# 19                   Lagta he script isi ne likhi he     1
# 20              Pushpa 2 ki puri story bol derah inna    3
# 21                                                       1
# 22  Director name is Sukumar .. Uska  ideas bahot ...
# 23  Lekin isme uske stepbrother ka kya role hai us...
# 24  Bhai real hai sach me jo abhi teaser aya bilku...    1
# 25                Bhai wo Julie nahi jolly reddy hai    13
# 26                    Sukumar bataya bhai Ko ye story
# 27                  This story is part 1 , not part 2
# 28       Tumne to part 2 ki puri movie dikha di .bro.
# 29  Ye to apne lakh rupay ki bat ki hainnnnn.. isk...
#
#                    time
# 0           2 weeks ago
# 1             1 day ago
# 2           11 days ago
# 3             1 day ago
# 4            9 days ago
# 5            3 days ago
# 6            2 days ago
# 7   5 days ago (edited)
# 8            9 days ago
# 9           3 weeks ago
# 10           3 days ago
# 11           3 days ago
# 12           9 days ago
# 13           2 days ago
# 14          13 days ago
# 15            1 day ago
# 16           7 days ago
# 17           9 days ago
# 18           9 days ago
# 19           3 days ago
# 20           6 days ago
# 21           2 days ago
# 22           5 days ago
# 23           8 days ago
# 24           6 days ago
# 25          12 days ago
# 26           2 days ago
# 27           2 days ago
# 28           3 days ago
# 29           9 days ago

# %% [markdown]
# # 9. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall
# reviews, privates from price, dorms from price, facilities and property description.

# %%
driver=webdriver.Chrome(r'chromedriver')

# %%
driver.get('https://www.hostelworld.com/')

# %%
search= driver.find_element(By.ID,'location-text-input-field')
search.send_keys('London')

# %%
find=driver.find_element(By.XPATH,'//ul[@id="predicted-search-results"]/li[2]')
find.click()

# %%
let_go=driver.find_element(By.XPATH,'//div[@class="search-button"]')
let_go.click()

# %%
url=[]
try:
    url_tags=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]/a')
    for i in url_tags:
        url.append(i.get_attribute('href'))
        
        
        
        
except NoSuchElementException:
    url.append('No Details')

# %%
url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hostel-One-Notting-Hill/London/291433?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-Inn-Hostel/London/517?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Camden/London/505?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Hammersmith/London/20976?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Queen-Elizabeth-Chelsea/London/50443?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Saint-James-Backpackers/London/70909?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Greenwich/London/501?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Shepherds-Bush/London/506?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Bell-House-Hostel/London/315821?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-White-Ferry-Victoria/London/39761?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hostelle-London/London/316723?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Kensal-Green-Backpackers/London/4483?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Crown-Battersea/London/60336?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Waterloo-Hostel/London/39493?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Elmwood-Hotel/London/34338?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Exmouth-Arms-Euston/London/93796?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Green-Man-Paddington/London/21953?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-House-Hotel/London/529?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Kip-Hotel/London/266789?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hanover-Hotel/London/6252?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Budget-London-Apartments/London/11493?from=2023-04-21&to=2023-04-24&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/The-London-Home-Hostel/London/80690?from=2023-04-21&to=2023-04-24&guests=2']

# %%
print(len(url))
# Out:
# 26

# %%
hostel=[]
distance=[]
rating=[]
total_review=[]
overall_review=[]
private_room=[]
dorm_price=[]
description=[]

facility=[]

# %%
driver=webdriver.Chrome(r'chromedriver')
for details in url:
    driver.get(details)
    time.sleep(5)
    


    try:
        hostel_tags=driver.find_elements(By.XPATH,'//div[@class="title-2"]')
        for i in hostel_tags[0:27]:
            hostel.append(i.text)
    except NoSuchElementException:
        hostel.append('No Details')

    try:
        distance_tags=driver.find_elements(By.XPATH,'//div[@class="content"]/div')
        for i in distance_tags[0:27]:
            distance.append(i.text)
    except NoSuchElementException:
        distance.append('No Details')
    
    try:
        rating_tags=driver.find_elements(By.XPATH,'//div[@class="initial-property-info"]/div[1]/div[1]/div[1]')
        for i in rating_tags[0:27]:
            rating.append(i.text)
        
    except NoSuchElementException:
        rating.append('No Details')
    
    try:
        total_review_tags=driver.find_elements(By.XPATH,'//div[@class="initial-property-info"]/div[1]/div[1]/div/div[2]')
        for i in total_review_tags:
            total_review.append(i.text.split(' ')[0])
        
    except NoSuchElementException:
        total_review.append('No Details')
    
    
    try:
        review_tags=driver.find_elements(By.XPATH,'//div[@class="initial-property-info"]/div[1]/div[1]/div/div[1]')
        for i in review_tags:
            overall_review.append(i.text)
        
    except NoSuchElementException:
        overall_review.append('No Details')
    
# privte room pending
    

    try:
        dorm_price_tags=driver.find_elements(By.XPATH,'//div[@class="availability-table"]/div[2]/div[2]/div[2]/div[1]/div/div[1]/div[2]/div')
        for i in dorm_price_tags:
            dorm_price.append(i.text)
    
        
    except NoSuchElementException:
        dorm_price.append('No Details')
    
    try:
        facility_tags= driver.find_elements(By.XPATH,'//div[@class="facilities-container"]/ul/li[1]/ul')
        for i in facility_tags:
            facility.append(i.text)
            
    except NoSuchElementException:
        facility.append('No Details')

    try:
        description_tags= driver.find_elements(By.XPATH,'//div[@class="flex-80"]/div/div/div[2]')
        for i in description_tags:
            description.append(i.text)
    except NoSuchElementException:
        description.append('No Details')

# %%
print(len(hostel),len(distance),len(rating),len( total_review),len(overall_review),len(dorm_price),len(facility),len(description))
# Out:
# 26 26 26 26 26 26 26 26

# %%
hostel=hostel[0:26]
distance=distance[0:26]
rating=rating[0:26]
total_review=total_review[0:26]
overall_review=overall_review[0:26]
dorm_price=dorm_price[0:26]
facility=facility[0:26]

# %%
print(len(hostel),len(distance),len(rating),len( total_review),len(overall_review),len(dorm_price),len(facility))
# Out:
# 27 27 27 27 27 27 27

# %%
df=pd.DataFrame({'hostel':hostel,'distance':distance,'rating':rating,'total_review':total_review,'overall_review':overall_review,'dorm_price':dorm_price,'facility':facility,'description':description})
df
# Out:
#                                  hostel  \
# 0              St Christopher's Village
# 1              St Christopher's Village
# 2               Hostel One Notting Hill
# 3                      Generator London
# 4     Safestay London Elephant & Castle
# 5                  Urbany Hostel London
# 6            Smart Hyde Park Inn Hostel
# 7               St Christopher's Camden
# 8          St Christopher's Hammersmith
# 9               Queen Elizabeth Chelsea
# 10              Saint James Backpackers
# 11           St Christopher's Greenwich
# 12      St Christopher's Shepherds Bush
# 13                    Bell House Hostel
# 14  PubLove @ The White Ferry, Victoria
# 15                      Hostelle London
# 16             Kensal Green Backpackers
# 17       PubLove @ The Crown, Battersea
# 18               London Waterloo Hostel
# 19                        Elmwood Hotel
# 20   PubLove @ The Exmouth Arms, Euston
# 21  PubLove @ The Green Man, Paddington
# 22                   London House Hotel
# 23                            Kip Hotel
# 24                        Hanover Hotel
# 25             Budget London Apartments
#
#                                              distance  \
# 0            165 Borough High Street, London, England
# 1            165 Borough High Street, London, England
# 2                 63 Prince's Square, London, England
# 3   Compton Place, Off 37 Tavistock Place, WC1, Lo...
# 4              144-152 Walworth Road, London, England
# 5   48-49 Princes Square, Paddington, London, England
# 6   48 - 50 Inverness Terrace, Bayswater, London, ...
# 7   48-50 Camden High Street, Camden NW1, London, ...
# 8   28, Hammersmith Broadway, Hammersmith, London,...
# 9                    58 Bagleys Lane, London, England
# 10                 21 Longridge Road, London, England
# 11  189 Greenwich High Road, Greenwich, London, En...
# 12  Belushis Bar, 13-15 Shepherds Bush Green., Lon...
# 13            91 Bell St, Bell House, London, England
# 14    1a Sutherland Street, Victoria, London, England
# 15            458 Bethnal Green road, London, England
# 16                   639 Harrow Road, London, England
# 17     102 Lavender Hill,, Battersea, London, England
# 18           73 Lambeth Walk, London, London, England
# 19     19 & 20 Argyle square, London, London, England
# 20                1 Starcross Street, London, England
# 21                  308 Edgware Road, London, England
# 22  81 Kensington Garden Square, Bayswater W2 4DJ,...
# 23                   2 Aspland Grove, London, England
# 24    30 St. Georges Drive, Victoria, London, England
# 25  30 Chatsworth Rd., Willesden Green, London, En...
#
#                         rating total_review overall_review  dorm_price  \
# 0                          7.7        12046      Very Good   Rs3995.50
# 1                          7.7        12046      Very Good   Rs4439.10
# 2                          9.5         1947         Superb   Rs3995.50
# 3                          7.4         7429      Very Good   Rs4439.10
# 4                          7.5         4897      Very Good    Standard
# 5                          9.2          724         Superb    Standard
# 6                          7.4         6562      Very Good    Standard
# 7                          7.8         4012      Very Good   Rs4593.45
# 8                          7.7         4219      Very Good   Rs5103.49
# 9                          6.9         3444           Good   Rs3320.90
# 10                         8.0         1873       Fabulous   Rs3689.88
# 11                         7.2         3329      Very Good    Standard
